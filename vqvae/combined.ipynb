# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import (
    load_codebooks,
    reduce_dimensionality_tsne,
    reduce_dimensionality_pca,
    visualize_codebooks_from_paths,
)
import os

# %%
file_paths = [
    "../results/original/original.npy", "../results/gaussian/gaussian.npy", "../results/poisson/poisson.npy", "../results/speckle/speckle.npy"
]  # Replace with actual file paths
labels = ["Codebook 1 (Original MNIST)", "Codebook 2 (Gaussian Noise)", "Codebook 3 (Poisson Noise)", "Codebook 4 (Speckle Noise)"]

# %%
visualize_codebooks_from_paths(file_paths, labels)
